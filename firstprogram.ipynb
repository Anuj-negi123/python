# %% [markdown]
# <a href="https://colab.research.google.com/github/Anuj-negi123/python/blob/main/firstprogram.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# this is  my first program
''' today is my first
python class  '''

print("hello world")
# Out:
# hello world
